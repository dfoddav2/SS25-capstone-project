# %% [markdown]
# # Exploratory Analysis of Mini cars

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mticker

# %%
# Load the Parquet file into a Pandas DataFrame
df = pd.read_parquet("all_car_details.parquet")
pd.set_option('display.float_format', '{:.2f}'.format)  # 2 decimal places

# df_mini = df[df["make"] == "mini"]
# len(df_mini)

df_mini = df[df["make"] == "kia"]
len(df_mini)
# Out:
# 17070

# %%
# Pie chart plot the different titles
df_mini["car_title"]
plt.pie(df_mini["car_title"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Pie chart plot the different titles
#       2 df_mini["car_title"]
# ----> 3 plt.pie(df_mini["car_title"])
#
# File ~/projects/capstone-project/.venv/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...
